# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math

sales_data = pd.read_csv("10000_Sales_Records.csv")

# %%
sales_data.head(5)
# Out:
#                          Region                           Country  \
# 0            Sub-Saharan Africa                              Chad
# 1                        Europe                            Latvia
# 2  Middle East and North Africa                          Pakistan
# 3            Sub-Saharan Africa  Democratic Republic of the Congo
# 4                        Europe                    Czech Republic
#
#          Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0  Office Supplies        Online              L   1/27/2011  292494523
# 1        Beverages        Online              C  12/28/2015  361825549
# 2       Vegetables       Offline              C   1/13/2011  141515767
# 3        Household        Online              C   9/11/2012  500364005
# 4        Beverages        Online              C  10/27/2015  127481591
#
#    Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# ...

# %%
sns.countplot(x="Country", data=sales_data)

# %%
sns.countplot(x="Region", data=sales_data)

# %%
sns.countplot(x="Item Type", data=sales_data)

# %%
sns.countplot(x="Total Cost", data=sales_data)

# %%
sales_data["Total Profit"].plot.hist(bins=20, figsize=(20,10))

# %%
sales_data["Units Sold"].plot.hist(bins=20, figsize=(20,10))

# %%
sales_data["Unit Cost"].plot.hist(bins=20, figsize=(20,10))

# %%
sales_data["Unit Price"].plot.hist(bins=20, figsize=(20,10))

# %%
sales_data["Total Cost"].plot.hist(bins=20, figsize=(20,20))

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Region            10000 non-null object
# Country           10000 non-null object
# Item Type         10000 non-null object
# Sales Channel     10000 non-null object
# Order Priority    10000 non-null object
# Order Date        10000 non-null object
# Order ID          10000 non-null int64
# Ship Date         10000 non-null object
# Units Sold        10000 non-null int64
# Unit Price        10000 non-null float64
# Unit Cost         10000 non-null float64
# Total Revenue     10000 non-null float64
# Total Cost        10000 non-null float64
# Total Profit      10000 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 1.1+ MB

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Item Type", hue="Sales Channel", data=sales_data)

# %%
sales_data.isnull()
# Out:
#       Region  Country  Item Type  Sales Channel  Order Priority  Order Date  \
# 0      False    False      False          False           False       False
# 1      False    False      False          False           False       False
# 2      False    False      False          False           False       False
# 3      False    False      False          False           False       False
# 4      False    False      False          False           False       False
# 5      False    False      False          False           False       False
# 6      False    False      False          False           False       False
# 7      False    False      False          False           False       False
# 8      False    False      False          False           False       False
# 9      False    False      False          False           False       False
# 10     False    False      False          False           False       False
# ...

# %%
sales_data.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
plt.figure(figsize=(25,8))
sns.boxplot(x="Unit Price", y="Units Sold", data=sales_data)

# %%
plt.figure(figsize=(25,6))
sns.boxplot(x="Unit Cost", y="Units Sold", data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Units Sold", hue="Item Type", data=sales_data)

# %%
plt.figure(figsize=(25,8))
sns.boxplot(x="Region", y="Units Sold", data=sales_data)

# %%
plt.figure(figsize=(25,8))
sns.boxplot(x="Region", y="Unit Cost", data=sales_data)

# %%
plt.figure(figsize=(25,9))
sns.boxplot(x="Region", y="Unit Price", data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Units Sold", hue="Sales Channel", data=sales_data)
