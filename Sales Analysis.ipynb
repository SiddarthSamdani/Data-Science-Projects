# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import sklearn
from sklearn.base import BaseEstimator



sales_data = pd.read_csv("100 Sales Records.csv")

# %%
sales_data.head(6)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# ...

# %%
sales_data.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Item Type",data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Item Type",hue="Sales Channel",data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Sales Channel",data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Country",data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Order Priority",data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Region",data=sales_data)

# %%
plt.figure(figsize=(30,9))
sns.countplot(x="Units Sold",data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Unit Price",data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Unit Cost",data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Total Revenue",hue="Sales Channel",data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Country",hue="Sales Channel",data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Region",hue="Sales Channel",data=sales_data)

# %%
plt.figure(figsize=(25,10))
sns.countplot(x="Country",hue="Item Type",data=sales_data)

# %%
plt.figure(figsize=(25,7))
sns.countplot(x="Total Profit",hue="Sales Channel",data=sales_data)

# %%
X = [[0, 0], [1, 1],[2, 2],[3, 3]]
Y = [0, 1, 2, 3]
clf = SomeClassifier()
clf = clf.fit(X, Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c8ef3d419cf6> in <module>
#       1 X = [[0, 0], [1, 1],[2, 2],[3, 3]]
#       2 Y = [0, 1, 2, 3]
# ----> 3 clf = SomeClassifier()
#       4 clf = clf.fit(X, Y)
#
# NameError: name 'SomeClassifier' is not defined

# %%
class FeatureMapper:
    def __init__(self, features):
        self.features = features        #features contains feature_name, column_name, and extractor( which is CountVectorizer) 

    def fit(self, X, y=None):
        for feature_name, column_name, extractor in self.features:
            extractor.fit(X[column_name], y) #my question is: is X features? if yes, where is it assigned? or else how can X call column_name by X[column_name].
